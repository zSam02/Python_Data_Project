# %% [markdown]
# #Tuples

# %%
luke_skill = ('python', 'java', 'c++')
print(id(luke_skill))
luke_skill
# Out:
# 132344577023744
# ('python', 'java', 'c++')

# %%
luke_skill[0:2]
# Out:
# ('python', 'java')

# %%
new_skills = ('excel', 'sql')
luke_skill += new_skills
luke_skill
# Out:
# ('python', 'java', 'c++', 'excel', 'sql')

# %%
id(luke_skill)
# Out:
# 132344945098352

# %%
range(4)
# Out:
# range(0, 4)

# %%
tuple(range(5))
# Out:
# (0, 1, 2, 3, 4)

# %%
tuple(range(1, 100, 10))
# Out:
# (1, 11, 21, 31, 41, 51, 61, 71, 81, 91)
