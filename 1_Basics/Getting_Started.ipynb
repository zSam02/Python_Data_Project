# %%
"This is a coding cell"
# Out:
# 'This is a coding cell'

# %% [markdown]
# This is a markdown cell

# %%
2+2
# Out:
# 4

# %%
2+2
3*2
# Out:
# 6

# %%
print(2+2)
print(3+3)
# Out:
# 4
# 6

# %%
#This is a comment

# %%
2+2 #This is a comment
# Out:
# 4

# %% [markdown]
# # Heading
# **bold**
#
# 1. one
# 2. two
# 3. Three
#
# [Here is a link to a video about Markdown](https://www.youtube.com/watch?v=wUSDVGivd-8&t=192s&ab_channel=LukeBarousse)

# %%
# !ls
# Out:
# sample_data

# %%
# %timeit [i**2 for i in range(1000)]
# Out:
# 307 µs ± 8.51 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
  L.append(n**2)
# Out:
# 518 µs ± 138 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
