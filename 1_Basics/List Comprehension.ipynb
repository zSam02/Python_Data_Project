# %%
numbers = [x for x in range(100)]

# %%
numbers = []

for number in range (100):
    numbers.append(number)

numbers

# %%
number = [x for x in ('PYTHON')]

number
# Out:
# ['P', 'Y', 'T', 'H', 'O', 'N']

# %%
number = {x for x in ('PYTHON')}

number
# Out:
# {'H', 'N', 'O', 'P', 'T', 'Y'}
