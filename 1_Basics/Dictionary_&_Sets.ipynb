# %% [markdown]
# #Dictionary{}

# %%
job_type_skills={
    'database': 'postgres',
   'language': 'python',
   'library': 'pandas'
}

# %%
job_type_skills
# Out:
# {'database': 'postgres', 'language': 'python', 'library': 'pandas'}

# %%
job_type_skills['database'] #key is database and key is postgres
# Out:
# 'postgres'

# %%
job_type_skills.keys()
# Out:
# dict_keys(['database', 'language', 'library'])

# %%
job_type_skills.values()
# Out:
# dict_values(['postgres', 'python', 'pandas'])

# %%
job_type_skills.pop('library')
# Out:
# 'pandas'

# %%
job_type_skills
# Out:
# {'database': 'postgres', 'language': 'python'}

# %%
job_type_skills.update({'cloud':'google_cloud'})

# %%
job_type_skills
# Out:
# {'database': 'postgres', 'language': 'python', 'cloud': 'google_cloud'}

# %%
job_type_skills['cloud']
# Out:
# 'google_cloud'

# %%
job_type_skills['version_control']='git' #Add another key and value to the library

# %%
job_type_skills
# Out:
# {'database': 'postgres',
#  'language': 'python',
#  'cloud': 'google_cloud',
#  'version_control': 'git'}

# %% [markdown]
# #Sets

# %%
#Designed for unique items

# %%
job_skills = {'tableau', 'sql', 'python', 'statistics'}

# %%
job_skills #can't index set
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.add('looker')
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.add('sql')

# %%
job_skills.pop()
# Out:
# 'python'

# %%
job_skills
# Out:
# {'looker', 'sql', 'statistics', 'tableau'}

# %%
job_skills.remove('tableau')

# %%
job_skills
# Out:
# {'looker', 'sql', 'statistics'}

# %%
skill_list = ['python', 'sql', 'tableau', 'python', 'sql']
list(set(skill_list))
# Out:
# ['tableau', 'sql', 'python']
