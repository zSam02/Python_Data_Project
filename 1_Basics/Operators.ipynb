# %% [markdown]
# #Operators

# %%
2 + 3.0
# Out:
# 5.0

# %%
"What's up" + " there"
# Out:
# "What's up there"

# %%
"Whats up?" *2
# Out:
# 'Whats up?Whats up?'

# %%
four = 4

four.__sub__(2)
# Out:
# 2

# %%
4 - 2
# Out:
# 2

# %%
5 / 3
# Out:
# 1.6666666666666667

# %%
5//3
# Out:
# 1

# %%
5 % 2
# Out:
# 1

# %%
print("5 divided by 2 is", 5//2, "with a remainder of", 5%2)
# Out:
# 5 divided by 2 is 2 with a remainder of 1

# %%
min_salary = 20_000
max_salary = 80_000
salary_range = max_salary - min_salary

avg_salary = (min_salary + max_salary) / 2

print(avg_salary)
print(salary_range)
# Out:
# 50000.0
# 60000

# %%
applicant_1 = "Kelly"
applicant_2 = "Luke"

# %%
applicant_1, applicant_2 = applicant_2, applicant_1

# %%
applicant_1, applicant_2
# Out:
# ('Luke', 'Kelly')

# %%
x =1

# %%
x= x+1

# %%
x
# Out:
# 2

# %%
x = 1

x += 1

# %%
x
# Out:
# 2

# %%
x = 1

# %%
x *= 2

# %%
x
# Out:
# 2

# %%
x+3
# Out:
# 5

# %%
x
# Out:
# 2

# %%
salary_kelly = 40_000
salary_luke = 30_000

# %%
salary_kelly == salary_luke
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
if (salary_kelly > salary_luke):
  print("Kelly's salary is higher than Luke's")
# Out:
# Kelly's salary is higher than Luke's

# %% [markdown]
# #Condtional Statements

# %%
#if #elif #else

# %%
if True:
            print("What's up")
# Out:
# What's up

# %%
#Applicant Skill
applicant_skill = 'Python'

# Skill required for job posting
job_skill = "SQL"

# %%
if job_skill == applicant_skill:
  print("Skill Match!")

# %%
years_experiance = 3
if job_skill == applicant_skill:
  print("Skill Match!")
elif years_experiance >= 5:
  print("Experienced enough: No SQL")
elif applicant_skill == "Python":
  print("This applicant should know SQL")
else:
  print("No Skill or Experiance")
# Out:
# This applicant should know SQL

# %%
if job_skill == applicant_skill:
  pass

# %% [markdown]
# #Lists

# %%
#Lists
job_skills = ['SQL', 'tableau', 'excel']

# %%
job_skills.append('python')

# %%
job_skills
# Out:
# ['SQL', 'tableau', 'excel', 'python']

# %%
job_skills.remove('tableau')

# %%
job_skills
# Out:
# ['SQL', 'excel', 'python']

# %%
len('python')
# Out:
# 6

# %%
len(job_skills)
# Out:
# 3

# %%
job_skills[1] #Second item is excel
# Out:
# 'excel'

# %%
job_skills.insert(2, 'tableau')

# %%
job_skills
# Out:
# ['SQL', 'excel', 'tableau', 'python']

# %%
job_skills.pop(2)
# Out:
# 'tableau'

# %%
job_skills
# Out:
# ['SQL', 'excel', 'python']

# %%
job_skills.pop()
# Out:
# 'python'

# %%
job_skills
# Out:
# ['SQL', 'excel']

# %%
#SLicing accesing multiple index values

# %%
job_skills = ['SQL', 'tableau', 'excel','looker']

# %%
job_skills[0:3]
# Out:
# ['SQL', 'tableau', 'excel']

# %%
job_skills[:]
# Out:
# ['SQL', 'tableau', 'excel']

# %%
job_skills[:1]
# Out:
# ['SQL']

# %%
job_skills[::1]
# Out:
# ['SQL', 'tableau', 'excel']

# %%
job_skills[::2]
# Out:
# ['SQL', 'excel']

# %%
luke_skills = ['python', 'bigquery', 'r']
kelly_skills = ['python', 'sql', 'looker']

# %%
all_skills = luke_skills + kelly_skills

all_skills
# Out:
# ['python', 'bigquery', 'r', 'python', 'sql', 'looker']

# %%
all_skills[::2] # Every two items
# Out:
# ['python', 'r', 'sql']

# %%
all_skills[5:]
# Out:
# ['looker']

# %%
all_skills[-1:] #Last item
# Out:
# ['looker']

# %%
skill1, skill2, skill3 = job_skills

# %%
print(skill1)
print(skill2)
print(skill3)
# Out:
# SQL
# tableau
# excel

# %%
skills_concerned, *skill_dont_care = job_skills #unpacked operater all skills go into*

# %%
print(skills_concerned)
print(skill_dont_care)
# Out:
# SQL
# ['tableau', 'excel']
