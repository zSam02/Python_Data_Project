# %%
# Install datasets Library (if not already installed)
#!pip install datasets

# Importing Libraries
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ...

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Bangladesh']).any()
# Out:
# True

# %%
uk_jobs = df[df['job_country'] == 'United Kingdom'] # == is the comparison operator
uk_jobs
# Out:
#               job_title_short  \
# 15              Data Engineer
# 45        Senior Data Analyst
# 74               Data Analyst
# 97               Data Analyst
# 152            Data Scientist
# ...                       ...
# 785485           Data Analyst
# 785513         Data Scientist
# 785522          Data Engineer
# 785642          Data Engineer
# 785676  Senior Data Scientist
#
#                                                 job_title    job_location  \
# 15                                          Data Engineer    Aberdeen, UK
# 45                                    Senior Data Analyst       Leeds, UK
# 74                       Data Entry/Economic Data Analyst   Worcester, UK
# 97      Systems & Data Analyst - Exploitation, Missing...  United Kingdom
# 152                                Data Science Team Lead        Anywhere
# ...                                                   ...             ...
# 785485                               Data Quality Analyst        Anywhere
# ...

# %%
uk_jobs = uk_jobs[uk_jobs['salary_year_avg'].notna()]

# %%
uk_jobs
# Out:
#               job_title_short                                       job_title  \
# 1107           Data Scientist         Data Scientist, Customer AI Engineering
# 2602             Data Analyst                            Admin & Data Analyst
# 9778      Senior Data Analyst  Workday HCM Senior Data Analyst (18 month FTC)
# 9903     Senior Data Engineer        Senior Satellite Analytics Data Engineer
# 13764          Data Scientist                    Programmatic Data Specialist
# ...                       ...                                             ...
# 781461         Data Scientist                                  Data Scientist
# 783284  Senior Data Scientist                           Senior Data Scientist
# 783436         Data Scientist                                 Insight Analyst
# 783598          Data Engineer                                   Data Engineer
# 783748          Data Engineer                                   Data Engineer
#
# ...

# %%
uk_jobs.groupby('job_title_short')[['salary_year_avg']].mean() #group by job title but analyse salary only works on numerical collumns
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst              49560.000000
# Data Analyst                  89410.916667
# Data Engineer                115622.200000
# Data Scientist               110250.933333
# Machine Learning Engineer    139564.428571
# Senior Data Analyst          107314.375000
# Senior Data Engineer         137550.020833
# Senior Data Scientist        129399.225806
# Software Engineer            103280.000000

# %%
uk_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'max', 'min', 'count']).sort_values(by='median', ascending=False)
# Out:
#                              median       max      min  count
# job_title_short
# Senior Data Scientist      157500.0  170575.0  72500.0     31
# Machine Learning Engineer  149653.0  200000.0  85205.0      7
# Senior Data Engineer       147500.0  171620.0  45000.0     24
# Senior Data Analyst        111175.0  118140.0  79200.0      8
# Data Engineer              110000.0  249000.0  35000.0     60
# Data Scientist             105300.0  205000.0  33488.5     75
# Software Engineer           89100.0  160000.0  89100.0      5
# Data Analyst                87750.0  180000.0  30000.0     72
# Business Analyst            56700.0   73500.0  30000.0      5
